# %% [markdown]
# <a href="https://colab.research.google.com/github/cgp9900/GANs/blob/connect_imagenet/ImageNet_GAN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## ImageNet GAN
